# %% [markdown]
# ### COMPARING MY DELIVERIES

# %%
import pandas as pd
import numpy as np
import regex as re
from numpy import nan
import seaborn as sns

# %%
intentos = {1: 'first_try.csv',2: 'regression.csv',
            3: 'third_try_xgb_BESTSCORE.csv',4: '4thtry_rfr_estimators=100.csv',
            5: '5thtry_xgboost_lin.csv',6: '5thtry_xgboost_tree_best.csv',
            7: '5thtry_xgboost_lin2.csv', 8: 'h2o.csv'}

# %%
df_0 = pd.read_csv('y_test.csv')

# %%
df_1 = pd.read_csv('first_try.csv')
df_2 = pd.read_csv('regression.csv')
df_3 = pd.read_csv('third_try_xgbr.csv')
df_4 = pd.read_csv('4thtry_rfr_estimators=100.csv')
df_5 = pd.read_csv('5thtry_xgboost_lin.csv')
df_6 = pd.read_csv('5thtry_xgboost_tree_best.csv')
df_7 = pd.read_csv('5thtry_xgboost_lin2.csv')
df_8 = pd.read_csv('h2o.csv')
df_9 = pd.read_csv('h2o_simplecolumns_50.8.csv')
df_10 = pd.read_csv('h2o_simplecolumns_60mod.csv')
df_11 = pd.read_csv('xgboost_simplecol.csv')
df_12 = pd.read_csv('xgboost_lin_newOUTLINER.csv')
df_13 = pd.read_csv('h2o_newoutli_40mod_43.csv')
df_14 = pd.read_csv('h2o_pd_numeric.csv')
df_15 = pd.read_csv('xgboost_lin_dummies.csv')

# %%
#for k,v in intentos.items():
#    df_[k] = pd.read_csv(intentos[k])

# %%
df_all = pd.DataFrame(df_0.price)

# %%
df_all['1_119.7']=df_1.price
df_all['2_140.81']=df_2.price

# %%
df_all['3_104.42']=df_3.price
df_all['4_107.56']=df_4.price
df_all['5_105.03']=df_5.price
df_all['6_108.98']=df_6.price
df_all['7_105.98']=df_7.price
df_all['8_hbo']=df_8.price
df_all['9_hbo_simpcol']=df_9.price
df_all['10_hbo_60mod']=df_10.price
df_all['11_XGboost_simpcol']=df_11.price
df_all['12_Lin_outlier']=df_12.price
df_all['13_h2o_40mod_newout']=df_13.price
df_all['14_h2o_pd_numeric']=df_14.price
df_all['15_Xboost_lin_dummies']=df_15.price

# %%
df_all
# Out:
#       price  1_119.7  2_140.81    3_104.42  4_107.56   5_105.03    6_108.98  \
# 0      89.0    64.05    137.09   95.999115    135.88   89.74566   96.470474
# 1      56.0    97.75    101.96   52.824930     94.40  213.24484   68.022670
# 2      95.0   150.97    123.81   61.160330    113.92  128.34108  100.538430
# 3     136.0   159.70    138.74   92.448040    117.54   83.89162  109.801200
# 4     135.0   142.49    147.05  103.490585    203.74  141.13089  131.732880
# ...     ...      ...       ...         ...       ...        ...         ...
# 1384  129.0   119.55     87.74  109.653480    133.42  108.99403   64.457565
# 1385   90.0   133.20    133.75  125.674255    112.68  153.62485  120.038376
# 1386  400.0   193.18    185.01  142.682920    139.60  181.82333  186.942180
# 1387  139.0   123.54    117.91  174.363020    211.53  128.89778   94.592180
# 1388   80.0   122.66     95.21  138.020680    136.24  154.79456  102.912000
#
# ...

# %%
df_all.describe()
# Out:
#              price      1_119.7     2_140.81     3_104.42     4_107.56  \
# count  1389.000000  1389.000000  1389.000000  1389.000000  1389.000000
# mean    166.707703   175.975954   173.640893   146.454773   145.152268
# std     119.447936    85.695599   112.075243    74.702179    61.867028
# min       0.000000    33.750000    34.200000   -34.639893    26.210000
# 25%      99.000000   124.170000   117.000000   102.052720   107.220000
# 50%     140.000000   157.220000   155.500000   130.804050   128.900000
# 75%     199.000000   206.480000   202.470000   171.011220   162.900000
# max    1880.000000  1176.490000  2497.570000   714.144000   564.110000
#
#           5_105.03     6_108.98     7_105.98        8_hbo  9_hbo_simpcol  \
# count  1389.000000  1389.000000  1389.000000  1389.000000    1389.000000
# mean    156.861446   135.778348   153.881081   153.608779     152.105986
# std      53.428140    49.444578    49.599086    52.281557      49.810285
# ...
